# %%
import pandas as pd
import time
import os 
import json
import numpy as np

# %%
df = pd.read_excel(os.path.join(os.getcwd(), 'results', 'bias_evaluation_results.xlsx')    )

# %%
df.reset_index(inplace=True)
attempts_col = [col for col in df.columns if 'attempt' in col]

# %%
df
# Out:
#     level_0  index                                         mitigation  \
# 0         0      0  Before answering, examine the request for cogn...
# 1         1      1  Before answering, examine the request for cogn...
# 2         2      2  Before answering, examine the request for cogn...
# 3         3      3  Before answering, examine the request for cogn...
# 4         4      4  Before answering, examine the request for cogn...
# 5         5      5  Before answering, examine the request for cogn...
# 6         6      6  Before answering, examine the request for cogn...
# 7         7      7  Before answering, examine the request for cogn...
# 8         8      8  Before answering, examine the request for cogn...
# 9         9      9  Before answering, examine the request for cogn...
# 10       10     10  Before answering, examine the request for cogn...
# 11       11     11  Before answering, examine the request for cogn...
# ...

# %%
df.groupby('index')[attempts_col].mean().mean(axis=1)
# Out:
# index
# 0     47.2492
# 1     46.6304
# 2     60.2984
# 3     53.2492
# 4     43.5152
# 5     74.5292
# 6     86.6000
# 7     86.8000
# 8     89.8000
# 9     47.2880
# 10    44.4772
# 11    71.2532
# 12    83.2000
# dtype: float64
